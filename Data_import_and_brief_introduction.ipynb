# %% [markdown]
# # Import, Wrangling and Basic Description
# ## Read me before setting out to code
# 1. The raw data frame is **data**, which is not allowed to be modified. All the modification should be on **df**, which is an copy of data. The reason is to prevent data missing.
# 2. I didn't cleaning the data. Rather, I gave a introduction on how to clean the data and what problem might arise when cleaning the data, as well as a small example.
# 3. Read these code helps you a lot when you're about to do visualizing and analysing.
# 4. Just comment some of the code if those long output table confuse you
#
# ## 1.1 Defind data importing functions, import packages

# %%
# created by TEAM SDPD Pull Over
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Data Wrangling : creates indexed dict with compiled data from files listed
files = ['actions_taken', 'basic_details', 'basis_of_search', 'basis_property_seizure', 'disability', 'evidence_found', 'gender', 'property_seized', 'race', 'reason_for_stop', 'stop_result']

def getFileData( filename ) :
    data = csv.reader(open('Data/' + filename + '.csv'))
    fields = data.__next__()
    rows = {}
    for (index, row) in enumerate(data) :
        items = zip(fields, row)
        item = {}
        for (name, value) in items :
            item[name] = value.strip()
        rows[index] = item
    return rows

def getFileData( filename ) :
    data = csv.reader(open("Data/" + filename + '.csv'))
    fields = data.__next__()
    rows = {}
    for (index, row) in enumerate(data) :
        items = zip(fields, row)
        item = {}
        for (name, value) in items :
            item[name] = value.strip()
        rows[index] = item
    return rows

def getUidDict( files ) :
    uid_dict = {}
    for file in files :
        fileData = getFileData( file )
        for rowIndex in fileData :
            row = fileData[rowIndex]
            stop_id = row['stop_id']
            pid = row['pid']
            uid = stop_id + "_" + pid
            uid_dict[uid] = {}
    for file in files :
        fileData = getFileData( file )
        for rowIndex in fileData :
            row = fileData[rowIndex]
            stop_id = row['stop_id']
            pid = row['pid']
            uid = stop_id + "_" + pid
            for field in row :
                uid_dict[uid][field] = row[field]
    return uid_dict

def getIndexedDict( uid_dict ) :
    dict = {}
    for (index, uid) in enumerate( uid_dict ) :
        dict[index] = uid_dict[ uid ]
        dict[index]['uid'] = uid
    return dict

# Example of how to get first index of data
#print(getIndexedDict( getUidDict(files) )[0])

# %% [markdown]
# ## 1.2 Import Data into **data** dataFrame
# This cell might take 30 seconds to execute to import all the data

# %%
data = pd.DataFrame(getIndexedDict( getUidDict(files)))
data = data.T

# %% [markdown]
# ## 1.3 Take a look at the data

# %%
data.head(7)
# Out:
#                            action agency  \
# 0                            None     SD
# 1                            None     SD
# 2              Curbside detention     SD
# 3              Curbside detention     SD
# 4                            None     SD
# 5  Search of person was conducted     SD
# 6       Handcuffed or flex cuffed     SD
#
#                                       assignment    basis_for_search  \
# 0  Patrol, traffic enforcement, field operations
# 1  Patrol, traffic enforcement, field operations
# 2                                          Other
# 3                                          Other
# 4  Patrol, traffic enforcement, field operations
# 5  Patrol, traffic enforcement, field operations  Incident to arrest
# 6                                          Other
#
#                         basis_for_search_explanation basisforpropertyseizure  \
# 0
# 1
# 2
# 3
# 4
# 5  subject was transported to detox and was searc...
# 6
#
#   beat            beat_name block   cityname   ...    \
# 0  122    Pacific Beach 122   700  SAN DIEGO   ...
# 1  121    Mission Beach 121        SAN DIEGO   ...
# 2  822       El Cerrito 822  4400  SAN DIEGO   ...
# 3  822       El Cerrito 822  4400  SAN DIEGO   ...
# 4  614      Ocean Beach 614  4800  SAN DIEGO   ...
# 5  115  University City 115  4500  SAN DIEGO   ...
# 6  122    Pacific Beach 122   800  SAN DIEGO   ...
#
#                                           resulttext school_name stop_id  \
# 0       647(F) PC - DISORD CONDUCT:ALCOHOL (M) 64005                2443
# 1  22349(B) VC - EXC 55MPH SPEED:2 LANE RD (I) 54395                2444
# 2                                                                   2447
# 3                                                                   2447
# 4                                                                   2448
# 5       647(F) PC - DISORD CONDUCT:ALCOHOL (M) 64005                2449
# 6       647(F) PC - DISORD CONDUCT:ALCOHOL (M) 64005                2451
#
#   stop_in_response_to_cfs             stopdate stopduration  stoptime  \
# 0                       0  2018-07-01 00:00:00           30  00:01:37
# 1                       0  2018-07-01 00:00:00           10  00:03:34
# 2                       1  2018-07-01 00:00:00           15  00:05:43
# 3                       1  2018-07-01 00:00:00           15  00:05:43
# 4                       0  2018-07-01 00:00:00            5  00:19:06
# 5                       1  2018-07-01 00:00:00           15  00:03:00
# 6                       0  2018-07-01 00:00:00           20  00:24:02
#
#                 street type_of_property_seized     uid
# 0         Grand Avenue                          2443_1
# 1          NOBEL DRIVE                          2444_1
# 2          59th Street                          2447_1
# 3          59th Street                          2447_2
# 4          NIAGARA AVE                          2448_1
# 5  la jolla village dr                          2449_1
# 6               Thomas                          2451_1
#
# [7 rows x 49 columns]

# %% [markdown]
# ## 1.4 All the rows

# %%
# show basic infomation of data
data.info()

# %% [markdown]
# ## 2.1 Brief introduction to data
# 1. count  - how many rows in the data
# 2. unique - number of different values
# 3. top    - largest value
# 4. freq   - count of top value

# %%
data.shape
# Out:
# (89470, 49)

# %%
data.describe().T
# Out:
#                               count unique  \
# action                        89470     23
# agency                        89470      1
# assignment                    89470     10
# basis_for_search              89470     13
# basis_for_search_explanation  89470   7210
# basisforpropertyseizure       89470      6
# beat                          89470    126
# beat_name                     89470    126
# block                         89470    221
# cityname                      89470     37
# code                          89470    788
# consented                     89470      3
# contraband                    89470     11
# disability                    89470      8
# exp_years                     89470     37
# gend                          89470      5
# gend_nc                       89470      2
# gender                        89470      5
# gender_nonconforming          89470      2
# highway_exit                  89470    748
# intersection                  89470   3948
# isschool                      89470      2
# isstudent                     89470      2
# land_mark                     89470     14
# officer_assignment_key        89470     10
# ori                           89470      1
# perceived_age                 89470    105
# perceived_gender              89470      5
# perceived_lgbt                89470      2
# perceived_limited_english     89470      2
# pid                           89470     20
# race                          89470      7
# reason_for_stop               89470      8
# reason_for_stop_code_text     89470    998
# reason_for_stop_detail        89470     16
# reason_for_stop_explanation   89470  47372
# reason_for_stopcode           89470   1002
# result                        89470     13
# resultkey                     89470     13
# resulttext                    89470    788
# school_name                   89470     51
# stop_id                       89470  79925
# stop_in_response_to_cfs       89470      2
# stopdate                      89470    184
# stopduration                  89470    248
# stoptime                      89470  38693
# street                        89470  16294
# type_of_property_seized       89470     12
# uid                           89470  89470
#
#                                                                         top  \
# action                                                                 None
# agency                                                                   SD
# assignment                    Patrol, traffic enforcement, field operations
# basis_for_search
# basis_for_search_explanation
# basisforpropertyseizure
# beat                                                                    521
# beat_name                                                  East Village 521
# block
# cityname                                                          SAN DIEGO
# code
# consented
# contraband                                                             None
# disability                                                             None
# exp_years                                                                 1
# gend                                                                      1
# gend_nc
# gender                                                                 Male
# gender_nonconforming                                                      0
# highway_exit
# intersection
# isschool                                                                  0
# isstudent                                                                 0
# land_mark
# officer_assignment_key                                                    1
# ori                                                               CA0371100
# perceived_age                                                            30
# perceived_gender                                                       Male
# perceived_lgbt                                                           No
# perceived_limited_english                                                 0
# pid                                                                       1
# race                                                                  White
# reason_for_stop                                        Reasonable Suspicion
# reason_for_stop_code_text
# reason_for_stop_detail                                     Moving Violation
# reason_for_stop_explanation                                        Speeding
# reason_for_stopcode
# result                                       Field interview card completed
# resultkey                                                                 7
# resulttext
# school_name
# stop_id                                                               47722
# stop_in_response_to_cfs                                                   0
# stopdate                                                2018-07-03 00:00:00
# stopduration                                                             10
# stoptime                                                           16:00:00
# street
# type_of_property_seized
# uid                                                                 13832_1
#
#                                freq
# action                        59871
# agency                        89470
# assignment                    80806
# basis_for_search              72683
# basis_for_search_explanation  77080
# basisforpropertyseizure       87454
# beat                           6987
# beat_name                      6987
# block                          8008
# cityname                      88101
# code                          39472
# consented                     88570
# contraband                    83372
# disability                    85180
# exp_years                     19743
# gend                          64586
# gend_nc                       89387
# gender                        64588
# gender_nonconforming          89387
# highway_exit                  88370
# intersection                  82397
# isschool                      89364
# isstudent                     89399
# land_mark                     89452
# officer_assignment_key        80806
# ori                           89470
# perceived_age                 12594
# perceived_gender              64586
# perceived_lgbt                86995
# perceived_limited_english     86408
# pid                           79925
# race                          39502
# reason_for_stop               42492
# reason_for_stop_code_text      6572
# reason_for_stop_detail        27403
# reason_for_stop_explanation    4043
# reason_for_stopcode            6572
# result                        19592
# resultkey                     19592
# resulttext                    39472
# school_name                   89364
# stop_id                          20
# stop_in_response_to_cfs       78135
# stopdate                        730
# stopduration                  18909
# stoptime                        294
# street                         3960
# type_of_property_seized       87454
# uid                               1

# %% [markdown]
# ## 2.2 Create **df** object and drop rows
# Here I use deep copy, which means that the modification on **df** will not influence **data**
# The rows that will be dropped is **agency** and **ori**
# These two columns have the same value for all the rows and provide no useful values

# %%
df = data.copy(deep=True)
df = df.drop(["agency","ori"],axis = 1)
print("data.columns:" + str(len(data.columns)))
print("df.columns:" + str(len(df.columns)))
# Out:
# data.columns:49
# df.columns:47

# %% [markdown]
# ## 2.3 Show all the distictive data in a row
# Here I use row "race" as an example

# %%
df['action'].unique()
# Out:
# array(['None', 'Curbside detention', 'Search of person was conducted',
#        'Handcuffed or flex cuffed', 'Field sobriety test conducted',
#        'Search of property was conducted', 'Physical or Vehicle contact',
#        'Person removed from vehicle by order', 'Chemical spray used',
#        'Property was seized', 'Patrol car detention', 'Vehicle impounded',
#        'Person removed from vehicle by physical contact',
#        'Asked for consent to search person',
#        'Asked for consent to search property', 'Person photographed',
#        'Canine removed from vehicle or used to search',
#        'Electronic control device used',
#        'Admission or written statement obtained from student',
#        'Firearm pointed at person', 'Baton or other impact weapon used',
#        'Canine bit or held person',
#        'Impact projectile discharged or used'], dtype=object)

# %% [markdown]
# ## 2.4 Notice: Data Cleaning Example
# All the data is the frame is "string" as shown below.
# Please convert it into numerate if it is needed
#
#
# I wrote a small example for converting a column into numerate type.
# It is worth mentioning that "null" in original table is empty string "".
# Please replace it with **np.nan** or **default value** like 0

# %%
# All the columns are in str type
for i in range(len(df.columns)):
    print("Column type: "+str(type(df.iloc[i][0]))+"\tColunm name:\t"+df.columns[i])
# Out:
# Column type: <class 'str'>	Colunm name:	action
# Column type: <class 'str'>	Colunm name:	assignment
# Column type: <class 'str'>	Colunm name:	basis_for_search
# Column type: <class 'str'>	Colunm name:	basis_for_search_explanation
# Column type: <class 'str'>	Colunm name:	basisforpropertyseizure
# Column type: <class 'str'>	Colunm name:	beat
# Column type: <class 'str'>	Colunm name:	beat_name
# Column type: <class 'str'>	Colunm name:	block
# Column type: <class 'str'>	Colunm name:	cityname
# Column type: <class 'str'>	Colunm name:	code
# Column type: <class 'str'>	Colunm name:	consented
# Column type: <class 'str'>	Colunm name:	contraband
# Column type: <class 'str'>	Colunm name:	disability
# Column type: <class 'str'>	Colunm name:	exp_years
# Column type: <class 'str'>	Colunm name:	gend
# Column type: <class 'str'>	Colunm name:	gend_nc
# Column type: <class 'str'>	Colunm name:	gender
# Column type: <class 'str'>	Colunm name:	gender_nonconforming
# Column type: <class 'str'>	Colunm name:	highway_exit
# Column type: <class 'str'>	Colunm name:	intersection
# Column type: <class 'str'>	Colunm name:	isschool
# Column type: <class 'str'>	Colunm name:	isstudent
# Column type: <class 'str'>	Colunm name:	land_mark
# Column type: <class 'str'>	Colunm name:	officer_assignment_key
# Column type: <class 'str'>	Colunm name:	perceived_age
# Column type: <class 'str'>	Colunm name:	perceived_gender
# Column type: <class 'str'>	Colunm name:	perceived_lgbt
# Column type: <class 'str'>	Colunm name:	perceived_limited_english
# Column type: <class 'str'>	Colunm name:	pid
# Column type: <class 'str'>	Colunm name:	race
# Column type: <class 'str'>	Colunm name:	reason_for_stop
# Column type: <class 'str'>	Colunm name:	reason_for_stop_code_text
# Column type: <class 'str'>	Colunm name:	reason_for_stop_detail
# Column type: <class 'str'>	Colunm name:	reason_for_stop_explanation
# Column type: <class 'str'>	Colunm name:	reason_for_stopcode
# Column type: <class 'str'>	Colunm name:	result
# Column type: <class 'str'>	Colunm name:	resultkey
# Column type: <class 'str'>	Colunm name:	resulttext
# Column type: <class 'str'>	Colunm name:	school_name
# Column type: <class 'str'>	Colunm name:	stop_id
# Column type: <class 'str'>	Colunm name:	stop_in_response_to_cfs
# Column type: <class 'str'>	Colunm name:	stopdate
# Column type: <class 'str'>	Colunm name:	stopduration
# Column type: <class 'str'>	Colunm name:	stoptime
# Column type: <class 'str'>	Colunm name:	street
# Column type: <class 'str'>	Colunm name:	type_of_property_seized
# Column type: <class 'str'>	Colunm name:	uid

# %%
# Out:
# 'None'
